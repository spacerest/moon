# %%
from moon.jupyter_ui import JupyterUi

# %%
ui = JupyterUi()

# %%
ui.set_moon_phase("2020-02-01")
# Out:
# True

# %%
ui.show()

# %%
i = 0
for x in ui.image[2]:
    ui.image[2][i] = [0, 0, 255]
    i+=1
    
i = 0
for x in ui.image[1]:
    ui.image[1][i] = [0, 0, 255]
    i+=1
    
i = 0
for x in ui.image[0]:
    ui.image[0][i] = [100, 0, 2]
    i+=1

# %%
ui.save_to_disk("idk")
